# %%
import pandas as pd
dtf = pd.read_csv('./Warehouse - Warehouse.csv')
dtf.describe()
# Out:
#        CATEGORY_ID  PRODUCT_ID  STANDARD_COST   LIST_PRICE   REGION_ID  \
# count        100.0  100.000000     100.000000   100.000000  100.000000
# mean           1.0  134.940000    1553.757300  1973.728000    2.320000
# std            0.0   90.050695     876.052857  1159.327519    0.468826
# min            1.0    4.000000     688.350000   864.980000    2.000000
# 25%            1.0   11.000000     706.990000   949.890000    2.000000
# 50%            1.0  161.000000    1343.840000  1699.000000    2.000000
# 75%            1.0  185.000000    2128.670000  2699.990000    3.000000
# max            1.0  281.000000    4058.990000  5499.990000    3.000000
#
#          QUANTITY
# count  100.000000
# mean   120.920000
# std     64.018255
# min      6.000000
# 25%     63.000000
# 50%    115.500000
# 75%    175.250000
# max    251.000000

# %%
dtf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CATEGORY_ID     100 non-null    int64
#  1   CATEGORY_NAME   100 non-null    object
#  2   PRODUCT_ID      100 non-null    int64
#  3   PRODUCT_NAME    100 non-null    object
#  4   DESCRIPTION     100 non-null    object
#  5   STANDARD_COST   100 non-null    float64
#  6   LIST_PRICE      100 non-null    float64
#  7   COUNTRY_ID      100 non-null    object
#  8   REGION_ID       100 non-null    int64
#  9   LOCATION_ID     100 non-null    object
#  10  WAREHOUSE_ID    100 non-null    object
#  11  QUANTITY        100 non-null    int64
#  12  WAREHOUSE_NAME  100 non-null    object
#  13  ADDRESS         100 non-null    object
#  14  POSTAL_CODE     100 non-null    object
#  15  CITY            100 non-null    object
#  16  STATE           100 non-null    object
# ...

# %%
dtf.shape
# Out:
# (100, 20)

# %%
dtf.isnull()
# Out:
#     CATEGORY_ID  CATEGORY_NAME  PRODUCT_ID  PRODUCT_NAME  DESCRIPTION  \
# 0         False          False       False         False        False
# 1         False          False       False         False        False
# 2         False          False       False         False        False
# 3         False          False       False         False        False
# 4         False          False       False         False        False
# ..          ...            ...         ...           ...          ...
# 95        False          False       False         False        False
# 96        False          False       False         False        False
# 97        False          False       False         False        False
# 98        False          False       False         False        False
# 99        False          False       False         False        False
#
#     STANDARD_COST  LIST_PRICE  COUNTRY_ID  REGION_ID  LOCATION_ID  \
# ...

# %%
dtf_delete=dtf.dropna()
print(dtf_delete)
# Out:
#     CATEGORY_ID CATEGORY_NAME  PRODUCT_ID  \
# 0             1    Video Card           4
# 1             1    Video Card           4
# 2             1    Video Card           4
# 3             1    Video Card           4
# 4             1    Video Card           4
# ..          ...           ...         ...
# 95            1    Video Card         281
# 96            1    Video Card         281
# 97            1    Video Card         281
# 98            1    Video Card         281
# 99            1    Video Card         281
#
#                                PRODUCT_NAME  \
# 0                            AMD 100-505989
# 1                            AMD 100-505989
# 2                            AMD 100-505989
# 3                            AMD 100-505989
# 4                            AMD 100-505989
# ..                                      ...
# 95  Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING
# 96  Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING
# 97  Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING
# ...

# %%
dtf_replace=dtf.fillna(value='replace_val')
print(dtf_replace)
dtf_ffill=dtf.ffill()
print(dtf_ffill)
dtf_bfill=dtf.bfill()
print(dtf_bfill)
# Out:
#     CATEGORY_ID CATEGORY_NAME  PRODUCT_ID  \
# 0             1    Video Card           4
# 1             1    Video Card           4
# 2             1    Video Card           4
# 3             1    Video Card           4
# 4             1    Video Card           4
# ..          ...           ...         ...
# 95            1    Video Card         281
# 96            1    Video Card         281
# 97            1    Video Card         281
# 98            1    Video Card         281
# 99            1    Video Card         281
#
#                                PRODUCT_NAME  \
# 0                            AMD 100-505989
# 1                            AMD 100-505989
# 2                            AMD 100-505989
# 3                            AMD 100-505989
# 4                            AMD 100-505989
# ..                                      ...
# 95  Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING
# 96  Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING
# 97  Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING
# ...

# %%
sample=dtf.groupby('CATEGORY_NAME')
filt_grp=sample.get_group('Video Card')
print(filt_grp)
# Out:
#     CATEGORY_ID CATEGORY_NAME  PRODUCT_ID  \
# 0             1    Video Card           4
# 1             1    Video Card           4
# 2             1    Video Card           4
# 3             1    Video Card           4
# 4             1    Video Card           4
# ..          ...           ...         ...
# 95            1    Video Card         281
# 96            1    Video Card         281
# 97            1    Video Card         281
# 98            1    Video Card         281
# 99            1    Video Card         281
#
#                                PRODUCT_NAME  \
# 0                            AMD 100-505989
# 1                            AMD 100-505989
# 2                            AMD 100-505989
# 3                            AMD 100-505989
# 4                            AMD 100-505989
# ..                                      ...
# 95  Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING
# 96  Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING
# 97  Asus ROG-POSEIDON-GTX1080TI-P11G-GAMING
# ...
